# %%
from semg_sim.MU import MotorUnit
from semg_sim.sEMG import SurfaceEMG
from semg_sim.SD import SaveData

# %%
### Create a MotorUnit object.
motor_unit = MotorUnit()

# Changing values.
motor_unit.A = 10
motor_unit.B = -10
motor_unit.C = 2
motor_unit.plot_length = 3
motor_unit.scaling_factor = 3

# %%
motor_unit.plot_current_distribution_action_potential()
